# %%
# ================================================
# PERTEMUAN 1 - PENGANTAR DATA SCIENCE
# Nama : Deviana Azzahroh
# NIM  : 240401010127
# ================================================

print("=" * 50)
print("🚀 SELAMAT DATANG DI DATA SCIENCE")
print("=" * 50)

# ================================================
# SEL 1 : OUTPUT SEDERHANA
# ================================================
print("\n📚 Hello, Data Science!")
print("✨ Selamat datang di mata kuliah Pengantar Data Science!\n")

# ================================================
# SEL 2 : VARIABEL DAN TIPE DATA
# ================================================
nama = "Deviana Azzahroh"
nim = "240401010127"
prodi = "Informatika"
angkatan = 2024
ipk = 4.00
aktif = True

print("👩‍🎓 DATA MAHASISWA")
print("-" * 30)
print(f"Nama      : {nama}")
print(f"NIM       : {nim}")
print(f"Program   : {prodi}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk:.2f}")
print(f"Status    : {'Aktif ✅' if aktif else 'Tidak Aktif ❌'}")

# ================================================
# SEL 3 : LIST DAN PERULANGAN
# ================================================
tools = [
    "Python 🐍",
    "Google Colab 💻",
    "Jupyter Notebook 📒",
    "GitHub 🌐"
]

print("\n🛠 TOOLS DATA SCIENCE YANG AKAN DIPELAJARI")
print("-" * 40)

for i, tool in enumerate(tools, start=1):
    print(f"{i}. {tool}")

# ================================================
# SEL 4 : FUNGSI SEDERHANA
# ================================================
def perkenalan(nama, prodi, angkatan):
    return (
        f"\n🎉 Halo semuanya!\n"
        f"Saya {nama}\n"
        f"Mahasiswa {prodi}\n"
        f"Angkatan {angkatan}\n"
        f"Siap belajar Data Science! 🚀"
    )

print(perkenalan(nama, prodi, angkatan))

# ================================================
# PENUTUP
# ================================================
print("\n" + "=" * 50)
print("🎯 Terima kasih telah menjalankan program ini!")
print("👩‍💻 Deviana Azzahroh | 240401010127")
print("=" * 50)
# Out:
# ...
# 🚀 SELAMAT DATANG DI DATA SCIENCE
# ...
#
# 📚 Hello, Data Science!
# ✨ Selamat datang di mata kuliah Pengantar Data Science!
#
# 👩‍🎓 DATA MAHASISWA
# ------------------------------
# Nama      : Deviana Azzahroh
# NIM       : 240401010127
# Program   : Informatika
# Angkatan  : 2024
# IPK       : 4.00
# Status    : Aktif ✅
#
# 🛠 TOOLS DATA SCIENCE YANG AKAN DIPELAJARI
# ----------------------------------------
# 1. Python 🐍
# 2. Google Colab 💻
# 3. Jupyter Notebook 📒
# 4. GitHub 🌐
#
# 🎉 Halo semuanya!
# Saya Deviana Azzahroh
# Mahasiswa Informatika
# Angkatan 2024
# Siap belajar Data Science! 🚀
#
# ...
# 🎯 Terima kasih telah menjalankan program ini!
# 👩‍💻 Deviana Azzahroh | 240401010127
# ...
